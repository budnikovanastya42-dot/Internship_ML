# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/budnikovanastya42-dot/Internship_week_1/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# My lane is Refresh / Content Opportunity Scoring. I am interested in the specific output this lane produces: generating a ranked review queue complete with scores, suggested actions, and explicit reason codes. I want to see the final output for myself and understand exactly how the entire process unfolds from raw data to actionable recommendations.

# %%
import pandas as pd
df = pd.read_csv("content_refresh_anonymized.csv")
print(f"Dataset ready for Opportunity Scoring: {df.shape[0]} rows")
# Out:
# Dataset ready for Opportunity Scoring: 30000 rows

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# The model improves the decision of which specific pages should be prioritized for review, addition, or updates.
# A site owner or solo webmaster acts on the ranked queue. They inspect the top-priority candidates and manually apply the necessary changes.
# Cost: Wasting valuable time fixing pages that are only experiencing normal seasonal traffic drops, while completely missing the pages that are actually losing true search visibility.

# %%
#no code needed

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
total_pages = len(df)
declining_pages = len(df[df['trend_direction'] == 'down'])
percent_declining = (declining_pages / total_pages) * 100

print(f"Number 1 (Scale): There are {total_pages} total content rows in the starter dataset.")
print(f"Number 2 (The Problem): {declining_pages} of these pages ({percent_declining:.1f}%) are currently showing a downward trend.")
# Out:
# Number 1 (Scale): There are 30000 total content rows in the starter dataset.
# Number 2 (The Problem): 16262 of these pages (54.2%) are currently showing a downward trend.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
print("--- 1. What we CAN observe ---")
expected_observable = [
    'impressions_90d',
    'clicks_90d',
    'content_age_days',
    'days_since_last_update',
    'ctr',
    'avg_position',
    'engagement_rate',
    'trend_direction'
]
actually_observed = [col for col in expected_observable if col in df.columns]
print(f"Verified metrics for directional claims:\n{actually_observed}")

print("\n--- 2. What we CANNOT observe ---")
forbidden_terms = ['url', 'domain', 'google_algorithm']
found_forbidden = [term for term in forbidden_terms if term in df.columns]

if not found_forbidden:
    print("Self-check passed: No raw URLs, or direct algorithm factors exist in this dataset.")
# Out:
# --- 1. What we CAN observe ---
# Verified metrics for directional claims:
# ['impressions_90d', 'clicks_90d', 'content_age_days', 'days_since_last_update', 'ctr', 'avg_position', 'engagement_rate', 'trend_direction']
#
# --- 2. What we CANNOT observe ---
# Self-check passed: No raw URLs, or direct algorithm factors exist in this dataset.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
